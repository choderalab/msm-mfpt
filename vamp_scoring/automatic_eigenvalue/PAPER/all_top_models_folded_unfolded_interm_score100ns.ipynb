# %%
import numpy as np

# %%
pwd
# Out:
# '/Users/rafalpwiewiora/repos/msm-mfpt/vamp_scoring/automatic_eigenvalue/PAPER'

# %%
chignolin_membs = np.load('../chignolin/chignolin_scorelag100ns_metastable_memberships.npy')

villin_membs = np.load('../villin/villin_scorelag100ns_metastable_memberships.npy')
villin_sets = np.load('../villin/villin_scorelag100ns_metastable_sets.npy')
np.save('villin_misfold_scorelag100ns', villin_sets[0])

trpcage_membs = np.load('../trpcage/trpcage_scorelag100ns_metastable_memberships.npy')

ntl9_membs = np.load('../ntl9/ntl9_scorelag100ns_metastable_memberships.npy')

# %%
############# BUG ALERT BUG ALERT BUG ALERT
# the way files are named is wrong below, because I have a %d - so what is saved as 0.8 is actually 0.85, saved 0.9 is
# actually 0.99, saved 0.99 is actually 0.999

# %%
cutoff = 0.8

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), ntl9_new)

# %%
cutoff = 0.85

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), ntl9_new)

# %%
cutoff = 0.9

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), ntl9_new)

# %%
cutoff = 0.95

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), ntl9_new)

# %%
cutoff = 0.99

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*10), ntl9_new)

# %%
cutoff = 0.999

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*100), chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*100), villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*100), trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_0_%d' % (cutoff*100), ntl9_new)

# %%
cutoff = 0.999999

chignolin_new = [np.argwhere(chignolin_membs[:,1] >= cutoff),
np.argwhere(chignolin_membs[:,0] >= cutoff)]

villin_new = [np.argwhere(villin_membs[:,1] >= cutoff),
np.argwhere(villin_membs[:,2] >= cutoff)]

trpcage_new = [np.argwhere(trpcage_membs[:,0] >= cutoff),
np.argwhere(trpcage_membs[:,1] >= cutoff)]

ntl9_new = [np.argwhere(ntl9_membs[:,1] >= cutoff),
np.argwhere(ntl9_membs[:,0] >= cutoff)]

np.save('chignolin_fold_unfold_scorelag100ns_cut_1', chignolin_new)
np.save('villin_fold_unfold_scorelag100ns_cut_1', villin_new)
np.save('trpcage_fold_unfold_scorelag100ns_cut_1', trpcage_new)
np.save('ntl9_fold_unfold_scorelag100ns_cut_1', ntl9_new)

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('ticks')
#sns.set_context('talk')
sns.set_style('ticks', {'font.sans-serif': ['DejaVu Sans']})

# %%
def intermediate_size(cutoff):
    chignolin_new_len = [len(np.argwhere(chignolin_membs[:,1] >= cutoff)),
    len(np.argwhere(chignolin_membs[:,0] >= cutoff))]

    villin_new_len = [len(np.argwhere(villin_membs[:,1] >= cutoff)),
    len(np.argwhere(villin_membs[:,2] >= cutoff))]

    trpcage_new_len = [len(np.argwhere(trpcage_membs[:,0] >= cutoff)),
    len(np.argwhere(trpcage_membs[:,1] >= cutoff))]

    ntl9_new_len = [len(np.argwhere(ntl9_membs[:,1] >= cutoff)),
    len(np.argwhere(ntl9_membs[:,0] >= cutoff))]

    return (200-np.sum(chignolin_new_len), 45-np.sum(villin_new_len), 100-np.sum(trpcage_new_len), 100-np.sum(ntl9_new_len))

# %%
intermediate_sizes = []

for cutoff in list(np.arange(0.8,1,0.001))+[0.999999]:
    intermediate_sizes.append(intermediate_size(cutoff))

# %%
plt.figure()

plt.plot(np.array(intermediate_sizes)[:,0], label='chignolin')
plt.plot(np.array(intermediate_sizes)[:,1], label='villin')
plt.plot(np.array(intermediate_sizes)[:,2], label='Trp-cage')
plt.plot(np.array(intermediate_sizes)[:,3], label='NTL9')

plt.legend()
sns.despine()
plt.xlabel('Macrostate membership cutoff')
plt.xticks([0,50,100,150,200], ['80%', '85%', '90%', '95%', '100%'])
plt.ylabel('# microstates in intermediate region')
plt.savefig('intermediate_region_size_v_pcca_cutoff_scorelag100ns.pdf')
plt.savefig('intermediate_region_size_v_pcca_cutoff_scorelag100ns.png', dpi=300)

# %%
# let's get more resolution 90% - 100%

# %%
plt.figure()

plt.plot(np.array(intermediate_sizes)[100:,0], label='chignolin')
plt.plot(np.array(intermediate_sizes)[100:,1], label='villin')
plt.plot(np.array(intermediate_sizes)[100:,2], label='Trp-cage')
plt.plot(np.array(intermediate_sizes)[100:,3], label='NTL9')

plt.legend()
sns.despine()
plt.xlabel('Macrostate membership cutoff')
plt.xticks([0,50,100], ['90%', '95%', '100%'])
plt.ylabel('# microstates in intermediate region')
plt.savefig('intermediate_region_size_v_pcca_cutoff_from_0_9_scorelag100ns.pdf')
plt.savefig('intermediate_region_size_v_pcca_cutoff_from_0_9_scorelag100ns.png', dpi=300)

# %%
# and just 95% - 100%

# %%
plt.figure()

plt.plot(np.array(intermediate_sizes)[150:,0], label='chignolin')
plt.plot(np.array(intermediate_sizes)[150:,1], label='villin')
plt.plot(np.array(intermediate_sizes)[150:,2], label='Trp-cage')
plt.plot(np.array(intermediate_sizes)[150:,3], label='NTL9')

plt.legend()
sns.despine()
plt.xlabel('Macrostate membership cutoff')
plt.xticks([0,10,20,30,40,50], ['95%', '96%', '97%', '98%', '99%', '100%'])
plt.ylabel('# microstates in intermediate region')
plt.savefig('intermediate_region_size_v_pcca_cutoff_from_0_95_scorelag100ns.pdf')
plt.savefig('intermediate_region_size_v_pcca_cutoff_from_0_95_scorelag100ns.png', dpi=300)
